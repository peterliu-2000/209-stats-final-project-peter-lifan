# %%
import pandas as pd
import matplotlib.pyplot as plt

random = pd.read_csv('../data/KuaiRand-1K/data/log_random_4_22_to_5_08_1k.csv')
video_features = pd.read_csv('../data/KuaiRand-1K/data/video_features_basic_1k.csv')
video_features_statistics = pd.read_csv('../data/KuaiRand-1K/data/video_features_statistic_1k.csv')

# %%
random.head()
# Out:
#    user_id  video_id      date  hourmin        time_ms  is_click  is_like  \
# 0        0      5543  20220430     1800  1651314030792         0        0
# 1        0      1836  20220502     1200  1651466607423         0        0
# 2        0       721  20220502     1700  1651481542743         0        0
# 3        0       442  20220502     1800  1651488577163         0        0
# 4        0        62  20220503      800  1651535940163         0        0
#
#    is_follow  is_comment  is_forward  is_hate  long_view  play_time_ms  \
# 0          0           0           0        0          0           863
# 1          0           0           0        0          0          1190
# 2          0           0           0        0          0          1528
# 3          0           0           0        0          0          1490
# 4          0           0           0        0          0          1419
#
#    duration_ms  profile_stay_time  comment_stay_time  is_profile_enter  \
# ...

# %%
video_features.head()
# Out:
#    video_id  author_id video_type   upload_dt  upload_type  visible_status  \
# 0         0    7349781     NORMAL  2022-04-10   LongImport             0.0
# 1         1    2103883     NORMAL  2022-04-10       Kmovie             0.0
# 2         2    5067285     NORMAL  2022-04-09  ShortImport             0.0
# 3         3    7048760     NORMAL  2022-04-11          Web             0.0
# 4         4    8635271     NORMAL  2022-04-09          Web             0.0
#
#    video_duration  server_width  server_height    music_id  music_type tag
# 0         87433.0         720.0         1280.0  9155697141         9.0  39
# 1        218066.0         720.0         1280.0  6355810746         9.0   2
# 2          9233.0         720.0         1280.0  6618412736         4.0   1
# 3         16433.0         720.0         1280.0  9161677205         9.0   7
# 4         38766.0         720.0         1280.0  9141092381         9.0   9

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))

plt.scatter(
    video_features['server_width'],
    video_features['server_height'],
    alpha=0.5,
    s=1
)

plt.xlim(0, 4400)
plt.ylim(0, 4400)
plt.xlabel('Server Width')
plt.ylabel('Server Height')
plt.title('Scatter Plot of Video Dimensions')

plt.grid(True)
plt.show()
